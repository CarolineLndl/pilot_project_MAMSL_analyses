# %% [markdown]
# @ author of the script:  <font color=#B2D732> Caroline Landelle </font>, caroline.landelle@mcgill.ca // landelle.caroline@gmail.com
#
#
# **Description:** This notebook provides basics information to use Notebooks
# Follow this links for details: https://pandas.pydata.org/pandas-docs/stable/getting_started/intro_tutorials/index.html

# %% [markdown]
# ## <font color=#B2D732> <span style="background-color: #4424D6"> Imports

# %%
# library that you want to import in your notebook
import sys
import pandas as pd
sys.path.append("/cerebro/cerebro1/dataset/caroline/2023_pilot_MA-MSL/derivatives/pilot_project_MAMSL_analyses/code/")

from movement_plotting import Movement_plots

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## <font color=#B2D732> <span style="background-color: #4424D6"> A/ Open a file and plot

# %% [markdown]
# #### 1. Here create a code select the files and run the ploting
# > Note that the main directory is: /cerebro/cerebro1/dataset/caroline/2023_pilot_MA-MSL/
# > start with that file: derivatives/data/sub-007/sess_MA/fam1/sub-007_sess01_fam1_movement.csv

# %%
main_dir="/cerebro/cerebro1/dataset/caroline/2023_pilot_MA-MSL/derivatives/data/"
subject_name="sub-009"
sess="MA"
run_name="RNDpre"
     
movement_table=pd.read_csv( main_dir + subject_name +"/sess_" + sess+ "/" + run_name + "/" + subject_name + "_sess01_" + run_name +"_movement.csv")
trial_table=pd.read_csv(main_dir + subject_name +"/sess_" + sess+ "/" + run_name + "/" + subject_name + "_sess01_" + run_name +"_trialfilter.csv")
mvmnt2plot=Movement_plots(movement_table,trial_table) # initialize the function

# %%
mvmnt2plot.plot_1d(trial_range=range(0,300))
