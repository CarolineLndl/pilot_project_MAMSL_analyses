# %% [markdown]
# ## <font color=#B2D732> <span style="background-color: #4424D6"> Imports

# %%
import sys,json
import glob, os
sys.path.append("/cerebro/cerebro1/dataset/caroline/2023_pilot_MA-MSL/derivatives/pilot_project_MAMSL_analyses/code/")


from movement_analyses import Movement_analyses

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## <font color=#B2D732> <span style="background-color: #4424D6"> A/ Initialization

# %% [markdown]
#  ### <font color=#4424D6> I. main directories </font >

# %%
# Load config file ------------------------------------------------------------
with open('../config/config_MAMSL.json') as config_file: # the notebook should be in 'xx/notebook/' folder #config_proprio
    config = json.load(config_file) # load config file should be open first and the path inside modified

config["subjects_acq"]={"sub-001":{"sess01":["RNDpre","MSL","RNDpost"],"sess02":["RNDpre","MA","RNDpost"]}}

mvmt_ana=Movement_analyses(config) # initialize the function
calib_table,movement_table,trial_table=mvmt_ana.readData() # read data and transform into tables

# %%
movement_table=mvmt_ana.reachAngles(calib_table,movement_table,trial_table)

# %%
movement_table=mvmt_ana.reachLine(calib_table,movement_table,trial_table)
# Out:
# /cerebro/cerebro1/dataset/caroline/2023_pilot_MA-MSL/derivatives/pilot_project_MAMSL_analyses/code/movement_analyses.py:122: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movement_table["line2Reach_Y"][first_trial_index:]=[arr[1] for arr in line2ReachConcat]
# /cerebro/cerebro1/dataset/caroline/2023_pilot_MA-MSL/derivatives/pilot_project_MAMSL_analyses/code/movement_analyses.py:123: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movement_table["trial_samples"]=[arr for arr in trial_samples]
# /cerebro/cerebro1/dataset/caroline/2023_pilot_MA-MSL/derivatives/pilot_project_MAMSL_analyses/code/movement_analyses.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
movement_table
# Out:
#        Unnamed: 0  axis_states_x  axis_states_y     axis_raw_x     axis_raw_y  \
# 0               0  6.947616e-310  6.947616e-310  6.947616e-310  6.947616e-310
# 1               1   0.000000e+00  -1.243523e-01   0.000000e+00   5.650000e+02
# 2               2  -1.030928e-02  -1.243523e-01   5.170000e+02   5.650000e+02
# 3               3  -2.061856e-02  -1.243523e-01   5.150000e+02   5.650000e+02
# 4               4  -3.608247e-02  -1.243523e-01   5.120000e+02   5.650000e+02
# ...           ...            ...            ...            ...            ...
# 40694       40694   6.250000e-01  -5.181347e-03   6.540000e+02   5.420000e+02
# 40695       40695   6.342593e-01  -5.181347e-03   6.560000e+02   5.420000e+02
# 40696       40696   6.944444e-01  -5.181347e-03   6.690000e+02   5.420000e+02
# 40697       40697   7.037037e-01  -5.181347e-03   6.710000e+02   5.420000e+02
# 40698       40698   6.990741e-01  -5.181347e-03   6.700000e+02   5.420000e+02
#
#        t_since_start    device_time         sample          trial  \
# 0      6.947616e-310  6.947616e-310  6.947624e-310  6.947616e-310
# 1       2.312846e+00   4.833800e+04   1.000000e+00  -1.000000e+00
# 2       1.822232e+01   2.104050e+05   2.000000e+00  -1.000000e+00
# 3       1.822480e+01   2.124020e+05   3.000000e+00  -1.000000e+00
# 4       1.822727e+01   2.144030e+05   4.000000e+00  -1.000000e+00
# ...              ...            ...            ...            ...
# 40694   1.917297e+02   7.182050e+05   5.785400e+04   3.190000e+02
# 40695   1.917320e+02   7.201830e+05   5.785500e+04   3.190000e+02
# 40696   1.917343e+02   7.221840e+05   5.785600e+04   3.190000e+02
# 40697   1.917348e+02   7.241730e+05   5.785700e+04   3.190000e+02
# 40698   1.917372e+02   7.261790e+05   5.785800e+04   3.190000e+02
#
#                phase  axis_statesfilt_x  axis_statesfilt_y  axis_rawfilt_x  \
# 0      6.947616e-310          -0.000392          -0.002861       -0.056164
# 1       5.000000e+00          -0.005759          -0.015045       51.458991
# 2       5.000000e+00          -0.011143          -0.026999      102.445274
# 3       5.000000e+00          -0.016510          -0.038588      152.396790
# 4       5.000000e+00          -0.021822          -0.049684      200.832149
# ...              ...                ...                ...             ...
# 40694   1.000000e+00           0.646295          -0.014595      658.599819
# 40695   1.000000e+00           0.651973          -0.012744      659.826226
# 40696   1.000000e+00           0.657041          -0.011152      660.920901
# 40697   2.000000e+00           0.661502          -0.009799      661.884325
# 40698   3.000000e+00           0.665366          -0.008667      662.719001
#
#        axis_rawfilt_y  reachAngs  line2Reach_X  line2Reach_Y  lineDistance  \
# 0            0.553152        NaN           NaN           NaN           NaN
# 1           58.252195        NaN           NaN           NaN           NaN
# 2          115.346124        NaN           NaN           NaN           NaN
# 3          171.261876        NaN           NaN           NaN           NaN
# 4          225.453988        NaN           NaN           NaN           NaN
# ...               ...        ...           ...           ...           ...
# 40694      543.817360   1.156169    704.160804    543.100503     50.160804
# 40695      543.460074   1.000790    705.120603    544.075377     49.120603
# 40696      543.152679   0.869005    706.080402    545.050251     37.080402
# 40697      542.891569   0.758464    707.040201    546.025126     36.040201
# 40698      542.672940   0.666913    708.000000    547.000000     38.000000
#
#         lineDev  trial_samples
# 0           NaN            NaN
# 1           NaN            NaN
# 2           NaN            NaN
# 3           NaN            NaN
# 4           NaN            NaN
# ...         ...            ...
# 40694 -2.008064          195.0
# 40695 -1.910184          196.0
# 40696 -1.347248          197.0
# 40697 -1.251740          198.0
# 40698 -1.281674          199.0
#
# [40699 rows x 20 columns]

# %%
movement_table[movement_table["trial"]<50]
# Out:
#   File "<ipython-input-271-10af2c8d1220>", line 1
#     movement_table[movement_table["trial"]=<50]
#                                           ^
# SyntaxError: invalid syntax

# %%
import seaborn as sns
g=sns.lineplot(x="trial_samples",y="lineDev",data=movement_table[movement_table["trial"]<100],color="#cdc466")
g=sns.lineplot(x="trial_samples",y="lineDev",data=movement_table[(movement_table["trial"]>=100) & (movement_table["trial"]<200)],color="#17a068")
g=sns.lineplot(x="trial_samples",y="lineDev",data=movement_table[(movement_table["trial"]>=200) & (movement_table["trial"]<300)],palette="#669ecd")
g.set(xlim=(0,50))

# %% [markdown]
#  ### <font color=#4424D6> II. select the file </font >

# %% [markdown]
# ## <font color=#B2D732> <span style="background-color: #4424D6"> B/ Analyses

# %% [markdown]
#  ### <font color=#4424D6> I. Reaction time </font >

# %% [markdown]
#  ### <font color=#4424D6> II. Create a dataframe for all participants</font >
